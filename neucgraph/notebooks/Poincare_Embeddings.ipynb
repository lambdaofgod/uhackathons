# %% [markdown]
# # Embedding graphs in hyperbolic spaces

# %% [markdown]
# ## Imports

# %%
from gensim.models.poincare import PoincareModel
from bokeh.models import HoverTool, LabelSet
from bokeh.plotting import figure, show, ColumnDataSource
from bokeh.io import output_notebook
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Utils
#
# `GeometryUtils.poincare_disk_to_halfspace` is the function that maps from [Poincare disk model](https://en.wikipedia.org/wiki/Poincar%C3%A9_disk_model) to [half-plane model](https://en.wikipedia.org/wiki/Poincar%C3%A9_half-plane_model). This is an isometry, I wanted to experiment if visualization in half-space works better

# %%
class RoamUtils:
    
    @staticmethod
    def get_roam_relations(org_roam_records_df):
        return  [
            (record.source_name, record.destination_name)
            for record in org_roam_records_df[["source_name", "destination_name"]].itertuples()
        ]

class GometryUtils:

    @staticmethod
    def poincare_disk_to_halfspace(poincare_vectors):
        """
        this mapping
        """
        z_poincare = poincare_vectors[:,0] + 1j * poincare_vectors[:,1]
        w_half_space = -1j * (z_poincare - 1j) / (z_poincare + 1j)
        return np.column_stack([np.real(w_half_space), np.imag(w_half_space)])


def plot_model_annotated_scatterplot(kv_model, shown_text_indices=None):
    text_annotated_scatterplot(kv_model.vectors, kv_model.index_to_key, shown_text_indices)


def text_annotated_scatterplot(data, text, shown_text_indices=None, **kwargs):
    """
    displays data in 2d as a scatterplot
    the i-th point shows text[i] on hover
    """
    # Invoke output command to enable showing the plot in notebook
    output_notebook()

    # Create a data source to enable refreshing of fill
    source = ColumnDataSource(data=dict(
        x=data[:,0],
        y=data[:,1],
        desc=text,
    ))

    # Generate the scatter plot
    p = figure(width=1280, height=1280, tools="pan,wheel_zoom,xbox_select,reset", toolbar_location=None)
    p.scatter('x', 'y', size=5, source=source)

    # Add a hover tool to display text
    hover = HoverTool()
    hover.tooltips = [
        ("index", "$index"),
        ("(x,y)", "($x, $y)"),
        ("desc", "@desc"),
    ]
    p.add_tools(hover)

    # If shown_text_indices is provided, add labels to the plot
    if shown_text_indices is not None:
        labels = LabelSet(x='x', y='y', text='desc', level='glyph',
                          x_offset=5, y_offset=5, 
                          source=ColumnDataSource(data=dict(
                              x=data[shown_text_indices,0],
                              y=data[shown_text_indices,1],
                              desc=[text[i] for i in shown_text_indices],
                          )))
        p.add_layout(labels)

    show(p)

# %%
org_roam_records_df = pd.read_parquet("../data/org_roam_records_2023_09_10.parquet")

# %% [markdown]
# The graph is exported from org-roam files, see `Org_roam_graph.livemd`

# %%
org_roam_records_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 621 entries, 0 to 620
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   destination_date       621 non-null    object
#  1   destination_name       621 non-null    object
#  2   destination_path       621 non-null    object
#  3   destination_root_path  621 non-null    object
#  4   source_date            621 non-null    object
#  5   source_name            621 non-null    object
#  6   source_path            621 non-null    object
#  7   source_root_path       621 non-null    object
# dtypes: object(8)
# memory usage: 38.9+ KB

# %% [markdown]
# ## Poincare embeddings from gensim
#
# These are the easiest to setup so we will start with them

# %%
roam_relations = get_roam_relations(org_roam_records_df)
len(roam_relations)
# Out:
# 621

# %%
model = PoincareModel(roam_relations, negative=4, size=2, alpha=0.01)
model.train(epochs=50)

# %%
model.kv.key_to_index # vocabulary
# Out:
# {'substructural_logic.org': 0,
#  'logic.org': 1,
#  'curry_howard.org': 2,
#  'rust_types.org': 3,
#  'c_algebras.org': 4,
#  'renormalization.org': 5,
#  'math.org': 6,
#  'ml_general.org': 7,
#  'general_nlp.org': 8,
#  'ml_articles.org': 9,
#  'metrics_mrr.org': 10,
#  'retrieval_nlp.org': 11,
#  'mgr_lcsh.org': 12,
#  'mgr.org': 13,
#  'readlog_logic.org': 14,
#  'wittgenstein.org': 15,
#  'logic_intensionality.org': 16,
#  'modal_logic.org': 17,
#  'epistemic_logic.org': 18,
#  'elixir_metaprogramming.org': 19,
#  'elixir.org': 20,
#  'org_ai_finance.org': 21,
#  'options_data_api.org': 22,
#  'multiple_instance_learning.org': 23,
#  'llms_interesting.org': 24,
#  'llms_rwkv.org': 25,
#  'llms_llama.org': 26,
#  'llms_news.org': 27,
#  'redpajama.org': 28,
#  'ggml.org': 29,
#  'llms.org': 30,
#  'nlp_piqa.org': 31,
#  'llms_evaluation.org': 32,
#  'apteki_intents.org': 33,
#  'apteki_intents_training_data.org': 34,
#  'pl_en_translation.org': 35,
#  'polish_nlp.org': 36,
#  'transformers_onnx.org': 37,
#  'zenml.org': 38,
#  'mlops.org': 39,
#  'zettelkasten_process.org': 40,
#  'zettelkasten.org': 41,
#  'adnotacje.org': 42,
#  'clarin.org': 43,
#  'marcinek.org': 44,
#  'projects.org': 45,
#  'mgr_generation_leak.org': 46,
#  'mgr_ir_generation_metrics.org': 47,
#  'mgr_previous_research.org': 48,
#  'mgr_data_model.org': 49,
#  'mgr_data_chapter.org': 50,
#  'nlp_pragmatics.org': 51,
#  'pragmatics.org': 52,
#  'wm_soa_conversation_data.org': 53,
#  'wm.org': 54,
#  'ai.org': 55,
#  'differential_forms.org': 56,
#  'diff_geo.org': 57,
#  'symbolic_elixir.org': 58,
#  'elixir_projects.org': 59,
#  'fixed_points_attractors.org': 60,
#  'dynamical_systems.org': 61,
#  'elixir_data_science.org': 62,
#  'project_travel_with_art.org': 63,
#  'travel_with_art_scraping.org': 64,
#  'rejestracje_ogolnie.org': 65,
#  'apteki.org': 66,
#  'rejestracje_nlu.org': 67,
#  'rustformers.org': 68,
#  'llms_rust.org': 69,
#  'nonenglish_nlp.org': 70,
#  'org_ai.org': 71,
#  'chatgpt_conversations.org': 72,
#  'org_ai_linux.org': 73,
#  'org_ai_python.org': 74,
#  'org_ai_nlp.org': 75,
#  'org_ai_emacs.org': 76,
#  'org_ai_ml.org': 77,
#  'org_ai_culture.org': 78,
#  'llms_plugins.org': 79,
#  'question_answering.org': 80,
#  'question_answering_tools.org': 81,
#  'qa_papers.org': 82,
#  'lm_qa.org': 83,
#  'chatgpt_conversations_lean.org': 84,
#  'lean_math.org': 85,
#  'llms_future.org': 86,
#  'quantum_mechanics.org': 87,
#  'physics.org': 88,
#  'schroedinger_proof.org': 89,
#  'qm_interference.org': 90,
#  'godelemacs.org': 91,
#  'golemacs_import_inference.org': 92,
#  'wm_code_design.org': 93,
#  'wm_define_table_in_rasa.org': 94,
#  'plt5.org': 95,
#  'cognitive_linguistics.org': 96,
#  'cogsci.org': 97,
#  'philosophy_of_objectivism.org': 98,
#  'umbertobot_working.org': 99,
#  'umbertobot.org': 100,
#  'optaplanner.org': 101,
#  'discrete_optimization.org': 102,
#  'qa_medsi_other.org': 103,
#  'qa_medsi.org': 104,
#  'zettelkasten_emacs.org': 105,
#  'org_dailies.org': 106,
#  'nushell.org': 107,
#  'polars.org': 108,
#  'livebook_components.org': 109,
#  'livebook.org': 110,
#  'phoenix_liveview.org': 111,
#  'elixir_phoenix.org': 112,
#  'marian_ort.org': 113,
#  'wm_bot.org': 114,
#  'rasa_slots.org': 115,
#  'linguistics.org': 116,
#  'pinker_metaphors.org': 117,
#  'montague_semantics.org': 118,
#  'org_ai_arxiv.org': 119,
#  'tiktoken.org': 120,
#  'wm_data_engineering.org': 121,
#  'wm_data_model.org': 122,
#  'project_ideas.org': 123,
#  'search_templates.org': 124,
#  'lmserver.org': 125,
#  'rust.org': 126,
#  'python_code_ast.org': 127,
#  'python.org': 128,
#  'wm_mvp_zadania.org': 129,
#  'wm_mvp.org': 130,
#  'library_science.org': 131,
#  'llama_index.org': 132,
#  'nlp_polish_setfit.org': 133,
#  'nlp_setfit.org': 134,
#  'wm_llm_eksperymenty.org': 135,
#  'wm_ubiquitious_lang.org': 136,
#  'nix.org': 137,
#  'build_tools.org': 138,
#  'scidiff.org': 139,
#  'smartdiff.org': 140,
#  'smartdiff_features.org': 141,
#  'scidiff_prototype.org': 142,
#  'nlp_hellaswag.org': 143,
#  'mutual_coherence.org': 144,
#  'linear_algebra.org': 145,
#  'llms_langchain.org': 146,
#  'ml_vector_databases.org': 147,
#  'langchain_qa_prompt.org': 148,
#  'huggingface_ocr.org': 149,
#  'ocr.org': 150,
#  'huggingface_api.org': 151,
#  'work_rejestracja_serwisy.org': 152,
#  'mlops_docker.org': 153,
#  'work_rejestracje_sprawy.org': 154,
#  'ml_backlog.org': 155,
#  'ml_papers.org': 156,
#  'papers_interesting.org': 157,
#  'ml_patterns.org': 158,
#  'llms_lora.org': 159,
#  'mgr_new_approach.org': 160,
#  'mgr_query_data_construction.org': 161,
#  'haystack.org': 162,
#  'org_ai_haystack.org': 163,
#  'papers_llm_data_generation.org': 164,
#  'mgr_nbow_data.org': 165,
#  'papers_arxiv_complex_qa_llm_hybrid_architectures.org': 166,
#  'papers_gbq_prompt_format.org': 167,
#  'papers_promptagator.org': 168,
#  'polish_summarization.org': 169,
#  'nlp_summarization.org': 170,
#  'wm_maszyna_stanowa.org': 171,
#  'wm_rasa.org': 172,
#  'wozny_cognitive_linguistics.org': 173,
#  'yfinance.org': 174,
#  'options.org': 175,
#  'wm_rasa_spacy_schema.org': 176,
#  'medsi.org': 177,
#  'reje_question_answering.org': 178,
#  'wm_alpaca.org': 179,
#  'infostrateg_warsztaty.org': 180,
#  'llms_retrieval_augmented.org': 181,
#  'reje_sprawy_backlog.org': 182,
#  'medsi_llm.org': 183,
#  'clearml_howto.org': 184,
#  'medsi_tabelki.org': 185,
#  'medsi_medsearch.org': 186,
#  'medsi_auth0.org': 187,
#  'kulfon.org': 188,
#  'llms_finetuning.org': 189,
#  'nlp_promptsource.org': 190,
#  'lmops.org': 191,
#  'nlp_text2table.org': 192,
#  'prompt_tricks.org': 193,
#  'nlp_prompts.org': 194,
#  'papers_instructor_embedding.org': 195,
#  'rellm.org': 196,
#  'finance.org': 197,
#  'fsm_bot.org': 198,
#  'chatbots.org': 199,
#  'manifold_neural_networks.org': 200,
#  'ml_ideas.org': 201,
#  'learning_tools.org': 202,
#  'question_generation.org': 203,
#  'summarization.org': 204,
#  'tool_experience.org': 205,
#  'clearml.org': 206,
#  'spacy.org': 207,
#  'clearml_config.org': 208,
#  'nlp_conversation_frameworks.org': 209,
#  'nlp_rasa.org': 210,
#  'ml_faces.org': 211,
#  'methodology.org': 212,
#  'wm_rasa_flow.org': 213,
#  'mvc.org': 214,
#  'software_design.org': 215,
#  'quantum_computing.org': 216,
#  'ideas.org': 217,
#  'llms_leaks.org': 218,
#  'ml_multivariate_distribution_tests.org': 219,
#  'ml_literature_search.org': 220,
#  'ml_drift.org': 221,
#  'ml_drift_tools.org': 222,
#  'llms_constrained_generation.org': 223,
#  'llms_utils.org': 224,
#  'conversational_llms.org': 225,
#  'medsi_rejestracja_plus.org': 226,
#  'llms_lmql.org': 227,
#  'golemacs.org': 228,
#  'golemacs_description.org': 229,
#  'note_methodology.org': 230,
#  'note_methodology_context.org': 231,
#  'pipelines.org': 232,
#  'pipelines_from_functions.org': 233,
#  'hofstadter_concepts_analogies.org': 234,
#  'research_ideas.org': 235,
#  'pragmabench.org': 236,
#  'summary_evaluation.org': 237,
#  'llms_evaluating_text_generation.org': 238,
#  'work_rejestracje.org': 239,
#  'books_ai_logic_epistemology.org': 240,
#  'llms_gofai.org': 241,
#  'logic_programming.org': 242,
#  'article_gradient_dissent.org': 243,
#  'gofai.org': 244,
#  'knowledge_graphs.org': 245,
#  'tasks.org': 246,
#  'work_data_generation.org': 247,
#  'conversation_data.org': 248,
#  'llm_knowledge_index.org': 249,
#  'llm_response_synthesis.org': 250,
#  'mgr_mvp_pipeline.org': 251,
#  'stokes.org': 252,
#  'medsearch_ui.org': 253,
#  'ui_ux.org': 254,
#  'search_ui.org': 255,
#  'prompting_dlai.org': 256,
#  'vega.org': 257,
#  'visualization.org': 258,
#  'elixir_arxiv.org': 259,
#  'owca.org': 260,
#  'llms_peft.org': 261,
#  'frege.org': 262,
#  'llm_quantization.org': 263,
#  'scaling_laws.org': 264,
#  'rasa_faq.org': 265,
#  'phoenix_architecture.org': 266,
#  'org_ai_command_to_roam.org': 267,
#  'openassistant_pythia.org': 268,
#  'wm_ocena_med.org': 269,
#  'clearml_pipelines.org': 270,
#  'clearml_pipeline_parameters.org': 271,
#  'clearml_pipeline_caching.org': 272,
#  'chatgpt_conversations_nix.org': 273,
#  'spacy_clearml_pipeline.org': 274,
#  'elixir_protocols.org': 275,
#  'wm_ewaluacja.org': 276,
#  'github_search.org': 277,
#  'monads.org': 278,
#  'emacs.org': 279,
#  'toolz_emacs.org': 280,
#  'rasa_gotchas.org': 281,
#  'smartdiff_prototype.org': 282,
#  'llms_emacs.org': 283,
#  'dependent_type_theory.org': 284,
#  'nlp_sentence_transformers.org': 285,
#  'deep_learning_categories.org': 286,
#  'categories.org': 287,
#  'rejestra_mlops.org': 288,
#  'work_mlops.org': 289,
#  'types_design.org': 290,
#  'medsi_llm_mvp.org': 291,
#  'existence_vs_essence.org': 292,
#  'language_games.org': 293,
#  'mgr_outline.org': 294,
#  'hopfield_networks.org': 295,
#  'energy_based_models.org': 296,
#  'hopfield_networks_geometry.org': 297,
#  'activations.org': 298,
#  'hopfield_separation_experiment.org': 299,
#  'mgr_backlog.org': 300,
#  'notehelper.org': 301,
#  'product.org': 302,
#  'medsi_bajki.org': 303,
#  'readlog.org': 304,
#  'readlog_cogsci.org': 305,
#  'innovators_dilemma.org': 306,
#  'value_networks.org': 307,
#  'elixir_github.org': 308,
#  'prompting_comparison.org': 309,
#  'textstat_pl.org': 310,
#  'textstat.org': 311,
#  'qa.org': 312,
#  'courses.org': 313,
#  'llms_mini.org': 314,
#  'polish_nlp_datasets.org': 315,
#  'polish_nlp_sbert.org': 316,
#  'polish_numbers.org': 317,
#  'polish_ner.org': 318,
#  'wm_mlops.org': 319,
#  'questions.org': 320,
#  'monads_returns.org': 321,
#  'hopfield_networks_idea.org': 322,
#  'information_retrieval.org': 323,
#  'readlog_search.org': 324,
#  'elixir_blog.org': 325,
#  'openassistant_models.org': 326,
#  'llms_memory.org': 327,
#  'org_ai_elixir.org': 328,
#  'mgr_chatgpt_data_generation.org': 329,
#  'mgr_chatgpt_vanilla_prompting_results.org': 330,
#  'hyperbolic_embeddings.org': 331,
#  'llms_generation.org': 332,
#  'rustlings.org': 333,
#  'org_ai_mgr.org': 334,
#  'botfront.org': 335,
#  'gpt_engineer.org': 336,
#  'llms_agents.org': 337,
#  'mgr_nbow.org': 338,
#  'toolz_emacs_pdf.org': 339,
#  'existence_vs_essence_ai.org': 340,
#  'oxidise_your_life.org': 341,
#  'wm_dsl.org': 342,
#  'design_patterns.org': 343,
#  'dsl_pattern.org': 344,
#  'org_ai_rasa.org': 345,
#  'topology_neural_networks.org': 346,
#  'algebraic_geometry_algorithms.org': 347,
#  'reje_sprawy_minimum.org': 348,
#  'homology.org': 349,
#  'article_huyen_building_llm_app.org': 350,
#  'lmops_gsheets.org': 351,
#  'nlp_drift.org': 352,
#  'demonstrate_search_predict.org': 353,
#  'minichain.org': 354,
#  'nemo_guardrails.org': 355,
#  'mgr_data_size.org': 356,
#  'mgr_function_signatures.org': 357,
#  'mgr_nbow_tasks.org': 358,
#  'rust_frontend.org': 359,
#  'chatgpt_conversations_emacs.org': 360,
#  'chatgpt_conversations_python.org': 361,
#  'chatgpt_conversations_rasa.org': 362,
#  'chatgpt_conversations_random.org': 363,
#  'chatgpt_conversations_wor.org': 364,
#  'chatgpt_conversations_linux.org': 365,
#  'ops.org': 366,
#  'emacs_interactive.org': 367,
#  'emacs_org_roam_langchain.org': 368,
#  'emacs_autocomplete.org': 369,
#  'work_rejestracje_mongo.org': 370,
#  'org_ai_clearml.org': 371,
#  'org_ai_templating.org': 372,
#  'org_ai_rest.org': 373,
#  'llms_deploy.org': 374,
#  'medsearch_sbert.org': 375,
#  'org_ai_frontend.org': 376,
#  'elixir_typespec.org': 377,
#  'search_templates_haystack.org': 378,
#  'mgr_mechanism.org': 379,
#  'small_data_training_flow.org': 380,
#  'rejestracje_ekstrakcja_informacji.org': 381,
#  'fibs.org': 382,
#  'customizing_regex_llm_generation.org': 383,
#  'medsi_ml.org': 384,
#  'setup.org': 385,
#  'llm_serving.org': 386,
#  'cltk.org': 387,
#  'huggingface.org': 388,
#  'small_data_nlp.org': 389,
#  'rwkv_raven.org': 390,
#  'task_status.org': 391,
#  'mgr_experiments.org': 392,
#  'mgr_experiments_code.org': 393,
#  'mgr_index_construction.org': 394,
#  'mgr_evaluation.org': 395,
#  'mgr_retrieval.org': 396,
#  'wm_livebook.org': 397,
#  'work_rejestracje_ml_strategy.org': 398,
#  'mgr_data_generation_ideas.org': 399,
#  'mgr_prompts.org': 400,
#  'lcsh.org': 401,
#  'ai_economics.org': 402,
#  'wm_question_generation.org': 403,
#  'blogposts.org': 404,
#  'llms_self_instruct.org': 405,
#  'twitter_chatgpt_cost.org': 406,
#  'llms_alpaca.org': 407,
#  'mlops_clearml_serving.org': 408,
#  'llms_speed.org': 409,
#  'ml_llms_biznes.org': 410,
#  'szczeklik.org': 411,
#  'rust_torch.org': 412,
#  'llms_knnlm.org': 413,
#  'mgr_bare_pipeline.org': 414,
#  'mgr_pipeline_grid.org': 415,
#  'mgr_metrics_experiment.org': 416,
#  'mgr_generated_data.org': 417,
#  'lm_qa_question_generation.org': 418,
#  'books.org': 419,
#  'book_lending.org': 420,
#  'mgr_representations.org': 421,
#  'uwr_courses.org': 422,
#  'reading_list.org': 423,
#  'medsi_mlops.org': 424,
#  'rasa_external_nlu.org': 425,
#  'llama_hardware.org': 426,
#  'clearml_gotchas.org': 427,
#  'wywiad_medyczny_flow.org': 428,
#  'wm_rasa_domain.org': 429,
#  'arxiv.org': 430,
#  'eposter.org': 431,
#  'eink.org': 432,
#  'lie_group_analysis.org': 433,
#  'lie_groups.org': 434,
#  'tree_of_thought.org': 435,
#  'openassistant.org': 436,
#  'openassistant_deploy.org': 437,
#  'livebook_macro.org': 438,
#  'retrieval_tools.org': 439,
#  'doom_conf.org': 440,
#  'statystyka_wielowymiarowa.org': 441,
#  'chatgpt_implicature.org': 442,
#  'post_llm_pragmatics.org': 443,
#  'llms_philosophy.org': 444,
#  'medsearch_design.org': 445,
#  'ml_conversational.org': 446,
#  'medsi_llm_finetuning.org': 447,
#  'org_ai_random.org': 448,
#  'implied_volatility.org': 449,
#  'immut.org': 450,
#  'trash.org': 451,
#  'readlog_qa.org': 452,
#  'mgr_defining_ir_problem.org': 453,
#  'small_lm_hypothesis.org': 454,
#  'ambiguity.org': 455,
#  'wm_rasa_planning.org': 456,
#  'infostrateg.org': 457,
#  'math_tricks.org': 458,
#  'reje_v1_3.org': 459,
#  'work_rejestracje_timex.org': 460,
#  'python_async_batch_runner.org': 461,
#  'python_async.org': 462,
#  'medsi_rozkminy.org': 463,
#  'work_apteki_instrukcja_obslugi.org': 464,
#  'logic_relevance.org': 465,
#  'ml_vision_text.org': 466,
#  'ml_metric_learning.org': 467,
#  'hopf_algebra.org': 468,
#  'voice_cloning.org': 469,
#  'lm_evaluation_harness.org': 470,
#  'medsi_lekointerakcjomat.org': 471,
#  'text_matching.org': 472,
#  'org_ai_project.org': 473,
#  'inbox.org': 474,
#  'lean_suggestions.org': 475,
#  'mgr_data_generation_review.org': 476,
#  'vpn.org': 477,
#  'lm_linguistics.org': 478,
#  'llms_logic.org': 479,
#  'lmclient.org': 480,
#  'nlp_summarization_deploy.org': 481}

# %%
text_annotated_scatterplot
# Out:
# <function __main__.text_annotated_scatterplot(data, text, shown_text_indices=None, **kwargs)>

# %%
len(model.kv.index_to_key), len(model.kv.vectors)
# Out:
# (482, 482)

# %%
plot_model_annotated_scatterplot(model.kv, list(range(0, 400, 20)))
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c6621335-3311-4b17-a44e-0f84a650d8be">Loading BokehJS ...</span>
#     </div>
#   <div id="d32f9dd3-cf58-4ec5-bd84-1deb33c58c9d" data-root-id="p1134" style="display: contents;"></div>
